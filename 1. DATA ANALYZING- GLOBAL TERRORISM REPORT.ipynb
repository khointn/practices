# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\DELL\Downloads\globalterrorismdb_0718dist.csv',encoding = "ISO-8859-1")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 0       197000000001   1970       7     2                  NaN         0
# 1       197000000002   1970       0     0                  NaN         0
# 2       197001000001   1970       1     0                  NaN         0
# 3       197001000002   1970       1     0                  NaN         0
# 4       197001000003   1970       1     0                  NaN         0
# 5       197001010002   1970       1     1                  NaN         0
# 6       197001020001   1970       1     2                  NaN         0
# 7       197001020002   1970       1     2                  NaN         0
# 8       197001020003   1970       1     2                  NaN         0
# 9       197001030001   1970       1     3                  NaN         0
# 10      197001050001   1970       1     1                  NaN         0
# 11      197001060001   1970       1     6                  NaN         0
# ...

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#CONCEPT: 
#0.Clean data
#1.Phân tích các Pattern chung của 1 cuộc khủng bố, bao gồm 3 hướng: 
     #Quốc gia vùng miền nào hay bị khủng bố nhất?
     #các tổ chức khủng bố và phạm vi hoạt động của chúng? 
     #tình hình khủng bố ở việt nam
#2.ML:Dự đoán xem cuộc khủng bố đó có thành công hay không?(Thế nào là 1 cuộc khủng bố thành công: Có người chết hoặc có người bị thương)
dict1={'year':data['iyear'],'month':data['imonth'],'day':data['iday'],'country':data['country'],'region':data['region'],
       'success':data['success'],'suicide':data['suicide'],'attacktype':data['attacktype1'],'terrorname':data['gname'],
       'PIC':data['nperps'],'death':data['nkill'],'wound':data['nwound']}
data_phantich=pd.DataFrame(dict1)

# %% [markdown]
# # Phân tích 1.1: Top 10 quốc gia và vùng miền bị khủng bố nhiều nhất

# %%
#check data:
data_phantich['country'].isnull().value_counts() #Tất cả các giá trị đều không trống(False:181691)-> không cần clean data
data_phantich['region'].isnull().value_counts()# như trên
data_phantich[data_phantich.country=='Unknown']['country'].value_counts()
data_phantich[data_phantich.country=='Unknown']['country'].value_counts()
# ==> Như vậy, ta không cần phải clean data cho các giá trị này
# Out:
# Series([], Name: country, dtype: int64)

# %%
#Top 10 quốc gia bị khủng bố nhiều nhất:
data_phantich['country'].value_counts().head(10)
#10 quốc gia đó là:
    #95: Iraq-Middle East & North Africa
    #153: Pakistan-Middle East & North Africa
    #4:Afghanistan-South Asia
    #92:India-South Asia
    #45:Columbia-South America
    #160:Phillipin-Southeast Asia
    #159:Peru-South America
    #61: El Salvador-Central America & Caribbean
    #603:Eritrea-Western Europe
    #209:Turkey-Middle East & North Africa
# Out:
# 95     24636
# 153    14368
# 4      12731
# 92     11960
# 45      8306
# 160     6908
# 159     6096
# 61      5320
# 603     5235
# 209     4292
# Name: country, dtype: int64

# %%
#plot đồ thị 10 quốc gia:
y=[24636,14368,12731,11960,8306,6908,6096,5320,5235,4292]
x=['Iraq', 'Parkistan', 'Afghanistan', 'India','Columbia','Phillipin','Peru','El Salvador','Eritrea','Turkey']
plot=plt.bar(x,y,color='red',align='edge')
plot[0].set_color('r')
plot[1].set_color('r')
plot[2].set_color('green')
plot[3].set_color('green')
plot[4].set_color('orange')
plot[5].set_color('blue')
plot[6].set_color('orange')
plot[7].set_color('black')
plot[8].set_color('purple')
plot[9].set_color('r')
plt.xlabel('top các nước')
plt.ylabel('số vụ khủng bố xảy ra')
plt.xticks(x, x, fontsize=9, rotation=30)
plt.title('Top 10 quốc gia xảy ra nhiều vụ khủng bố nhất')
plt.show()

# %%
y=list(data_phantich['year'].value_counts())
x=[2014,
2015,
2016,
2013,
2017,
2012,
2011,
1992,
2010,
2008,
2009,
1991,
1989,
1990,
1988,
1984,
1994,
2007,
1997,
1987,
1995,
1996,
1985,
1983,
1986,
2006,
1979,1980,1981,1982,2005,2001,2000,1978,1999,2002,1977,2003,2004,1998,1976,1975,1970,1974,1972,1973,1971]
plt.scatter(x,y)

# %% [markdown]
# # Phân tích 1.2: Các tổ chức khủng bố và phạm vi hoạt động của chúng

# %%
#Check data:
data_phantich['terrorname'].value_counts().head(21)
#Đây là 20 tổ chức hàng đầu (bỏ Unknown). Có 19/20 tổ chức có số vụ thực hiện trên 1000
#funfact nhỏ: Có communist party of India cũng được xem là 1 tổ chức khủng bố
#Mình quyết định chọn 2 tổ chức mà mình cảm thấy hứng thú để phân tích: 
    #Taliban
    #Communist Party of India - Maoist (CPI-Maoist)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# ...

# %%
#Plot data 1 chút:
datagroup=pd.DataFrame({'count' : data_phantich.groupby( [ "terrorname"] ).size().sort_values(ascending=False).head(21)}).reset_index()
datagroup=datagroup[datagroup.terrorname != 'Unknown']
plt.barh(datagroup['terrorname'],datagroup['count'],color='orange')
plt.title('Top 20 tổ chức khủng bố có số vụ khủng bố nhiều nhất')
# Out:
# Text(0.5, 1.0, 'Top 20 tổ chức khủng bố có số vụ khủng bố nhiều nhất')

# %% [markdown]
# Phân tích TALIBAN

# %%
#để phân tích các tổ chức, mình sẽ sử dụng xen kẽ lại tập dataset gốc ('data'), do nó có nhiều features.
#Phân tích tổ chức mình sẽ sử dụng các feature sau:
    #Theo thời gian
    #Địa bàn hoạt động
    #Attack type (chưa bao gồm suicide)
    #Quy mô

# %%
#Theo thời gian
data[data.gname=='Taliban']['iyear'].value_counts()
#Có thể thấy năm 1995 là năm lâu nhất trong các cuộc tấn công của Taliban -> Tổ chức bắt đầu hoạt động vào 1995
#Plot đồ thị:
y=list(data[data.gname=='Taliban']['iyear'].value_counts())
x=[2015,2016,2014,2017,2012,2013,2010,2009,2008,2011,2007,2006,2005,2004,2003,2002,1995,2001]
plt.scatter(x,y)

# %%
data[data.gname=='Taliban'].country_txt.value_counts()
#Mình dễ dàng thấy rằng phạm vi hoạt động của group Taliban chỉ nằm ở 3 quốc gia Afghanistan,Pakistan, Turkmenistan
# Out:
# Afghanistan     7423
# Pakistan          54
# Turkmenistan       1
# Name: country_txt, dtype: int64

# %%
#Do lúc nãy thống kê, mình có thấy rằng có 1 vài tổ chức khủng bố như Al-Qaida còn có nhiều chi nhánh ở các quốc gia khác,
#nên mình sẽ check thêm liệu Taliban có như vậy không
# xử lí 1 chút:
for i in data['gname']:
    if 'taliban' in str(i).lower():
        i='Taliban'
data[data.gname=='Taliban'].country_txt.value_counts()
# ==> mình thấy rằng con số không đổi, vậy là có thể yên tâm rằng chỉ có 1 tổ chức Taliban thôi
# Out:
# Afghanistan     7423
# Pakistan          54
# Turkmenistan       1
# Name: country_txt, dtype: int64

# %%
#plot đồ thị ( hơi xấu)
colors=['gray','orange','b']
label=['Afghanistan','Pakistan','Turkmenistan']
plt.pie(data[data.gname=='Taliban'].country_txt.value_counts(), labels=label,colors=colors, startangle=180, autopct='%.1f%%')
plt.title('Phạm vi hoạt động (quốc gia) của Taliban')
plt.show()

# %%
#Phân tích Attacktype của Taliban:
data[data.gname=='Taliban']['attacktype1_txt'].value_counts()
#Plot đồ thị:
fig, (ax1, ax2) = plt.subplots(1, 2)
dothi=[2866,2125,713,508,235,33+19+13+966]
label=['Bombing/Explosion','Armed Assault','Kidnapping','Assassination','Facility/Infrastructure Attack','Others+Unknown']
ax1.pie(dothi, startangle=180, autopct='%.1f%%')
#So sánh attack type của Taliban với attack type toàn thế giới:
data['attacktype1_txt'].value_counts()
#Plot đồ thị:
dothi1=[88255,42669,19312,11158,10356,7276+1015+991+659]
ax2.pie(dothi1, startangle=180, autopct='%.1f%%')
plt.legend(label,loc='lower right',bbox_to_anchor=(1, 1),fontsize=8)
plt.show()

#Vậy ta rút ra được kết luận sau:
#Các chỉ số về attacktype của Taliban gần như tương đồng với cả thế giới. Điều này cũng dễ hiểu vì Taliban là tổ chức có nhiều số vụ khủng bố nhất
#Taliban ít khả năng sử dụng Bombing trong 1 cuộc tấn công hơn so với chỉ số chung, thay vào đó là Armed Assault

# %%
#Quy mô:
#Để đơn giản, ta tính mức độ thiệt hại của 1 vụ khủng bố bằng công thức: death + wound
data_phantich['criticalrate']=data_phantich['death']+data_phantich['wound']
#Xử lí NA bằng cách drop:
datadeath=data_phantich.dropna(axis=0,subset=['death','wound','criticalrate'])
#Tính mức độ thiệt hại trung bình của Taliban so với thế giới:
datadeath[datadeath.terrorname=='Taliban']['criticalrate'].mean()#==7.9109529343405
datadeath['criticalrate'].mean() #==5.296128433353355
#=> Taliban có mức độ thiệt hại cao hơn so với mức trung bình toàn cầu trong 1 vụ tấn công 
data_phantich['deathrate']=data_phantich['death']/(data_phantich['death']+data_phantich['wound'])
datadeath['deathrate']=datadeath['death']/(datadeath['death']+datadeath['wound'])
datadeath['deathrate'].fillna(value=0,axis=0,inplace=True)
#Tính mức độ tử:
datadeath[datadeath.terrorname=='Taliban']['deathrate'].mean() #0.512434661134669
datadeath['deathrate'].mean() #0.32942326312248466
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# 0.32942326312248466

# %%
#Sum up thông tin ở trên về quy mô:
#SỐ NGƯỜI BỊ ẢNH HƯỞNG (CHẾT + BỊ THƯƠNG):
    #Trung bình trong 1 vụ khủng bố do Taliban gây nên, tỉ lệ người bị ảnh hưởng là 8 người. 
    #Cao hơn so với trung bình trong 1 vụ khủng bố ngẫu nhiên trên thế giới- 5 người
#TỈ LỆ NGƯỜI CHẾT (SỐ NGƯỜI CHẾT/SỐ NGƯỜI BỊ ẢNH HƯỞNG)
    #Trong 1 vụ khủng bố do Taliban gây nên, nếu bạn là người bị ảnh hưởng, bạn sẽ có 51,24% sẽ CHẾT !!
    #Hay nói cách khác, bạn sẽ chỉ có 48,76% sống sót!!!
    #Cao hơn nhiều so với 1 vụ khủng bố ngẫu nhiên trên thế giới- chỉ có 32,94% khả năng CHẾT và tới 67,06% sống

# %%
#SUM-UP TALIBAN:
#Tổng quan+ Theo thời gian:
    #Taliban là tổ chức khủng bố thực hiện nhiều cuộc tấn công nhất tính tổng tất cả các năm
    #Tổng số cuộc tấn công mà Taliban thực hiện là 7478 vụ, với 54,459 nạn nhân, trong đó có 26,590 người chết
    #Taliban bắt đầu các cuộc tấn công được biết đến vào năm 1995, với 4 vụ.
    
#Quốc gia và khu vực hoạt động: 
    #Taliban hoạt động chủ yếu ở 3 quốc gia là Afghanistan,Pakistan,Turkmenistan. 
    #Trong đó Afghanistan chiếm đến 99,3 tổng số cuộc tấn công của Taliban, tương đương với 7423 vụ.
    
#Hình thức khủng bố chủ yếu của Taliban và tương quan với thế giới:
    #Các chỉ số về attacktype của Taliban gần như tương đồng với cả thế giới với các loại hình:Bombing,Armed Assault,Kidnapping,Assassination,Facility/Infrastructure Attack
    #Điều này cũng dễ hiểu vì Taliban là tổ chức có nhiều số vụ khủng bố nhất.
    #Taliban ít khả năng sử dụng Bombing trong 1 cuộc tấn công hơn(38.3% so với 48,6%),thay vào đó là Armed Assault (28,4$ so với 23,5%)

#Quy mô và số người ảnh hưởng/ tương quan với thế giới:
    #SỐ NGƯỜI BỊ ẢNH HƯỞNG (CHẾT + BỊ THƯƠNG):
        #Trung bình trong 1 vụ khủng bố do Taliban gây nên, tỉ lệ người bị ảnh hưởng là 8 người. 
        #Cao hơn so với trung bình trong 1 vụ khủng bố ngẫu nhiên trên thế giới- 5 người
    #TỈ LỆ NGƯỜI CHẾT (SỐ NGƯỜI CHẾT/SỐ NGƯỜI BỊ ẢNH HƯỞNG)
        #Trong 1 vụ khủng bố do Taliban gây nên, nếu bạn là người bị ảnh hưởng, bạn sẽ có 51,24% sẽ CHẾT !!
        #Hay nói cách khác, bạn sẽ chỉ có 48,76% sống sót!!!
        #Cao hơn nhiều so với 1 vụ khủng bố ngẫu nhiên trên thế giới- chỉ có 32,94% khả năng CHẾT và tới 67,06% sống

# %% [markdown]
# Phân tích COMMUNIST PARTY IN INDIA

# %%
#Theo thời gian
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['iyear'].value_counts()
#Plot đồ thị:
y=list(data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['iyear'].value_counts())
x=[2010,2009,2011,2008,2017,2016,2015,2014,2012,2013,2006,2005,2007]
plt.scatter(x,y)
#CPI bắt đầu tổ chức tấn công được bến đến vào năm 2005, đỉnh điểm là 2010 với hơn 500 cuộc khủng bố.

# %%
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)'].country_txt.value_counts()
#CPI hoạt động chủ yếu ở Ấn Độ, với tổng số cuộc khủng bố là 1878, trong đó 1877 vụ là ở Ấn Độ, 1 vụ ở Nepal
# Out:
# India    1877
# Nepal       1
# Name: country_txt, dtype: int64

# %%
#Phân tích Attacktype của CPI:
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['attacktype1_txt'].value_counts()
#Plot đồ thị:
fig, (ax1, ax2) = plt.subplots(1, 2)
dothi=[547,577,307,52,282,68+21+52+7]
label=['Bombing/Explosion','Armed Assault','Kidnapping','Assassination','Facility/Infrastructure Attack','Others+Unknown']
ax1.pie(dothi, startangle=180, autopct='%.1f%%')
#So sánh attack type của CPI với attack type toàn thế giới:
data['attacktype1_txt'].value_counts()
#Plot đồ thị:
dothi1=[88255,42669,19312,11158,10356,7276+1015+991+659]
ax2.pie(dothi1, startangle=180, autopct='%.1f%%')
plt.legend(label,loc='lower right',bbox_to_anchor=(1, 1),fontsize=8)
plt.show()

#Vậy ta rút ra được kết luận sau:
#Các chỉ số của CPI khá khác so với thế giới. CPI có tỉ lệ sử dụng Armed Assault nhiều hơn Bombing, thế giới thì ngươc lại.
#CPI cũng có tỉ lệ nhiều cuộc tấn công vào cơ sở hạ tầng hơn, còn Assassination ít hơn. Thế giới thì ngược lại.
#Và có nhiều khả năng là 1 cuộc bắt cóc hơn.

# %%
#Quy mô:
#SỐ NGƯỜI ẢNH HƯỞNG:
datadeath[datadeath.terrorname=='Communist Party of India - Maoist (CPI-Maoist)']['criticalrate'].mean() #2.1639254385964914
datadeath['criticalrate'].mean() #5.296128433353355
#TỈ LỆ CHẾT:
datadeath[datadeath.terrorname=='Communist Party of India - Maoist (CPI-Maoist)']['deathrate'].mean() #0.407241325135677
datadeath['deathrate'].mean() #0.32942326312248466
# Out:
# 0.32942326312248466

# %%
#SUM-UP COMMINIST PARTY IN INDIA (CPI):
#Tổng quan+ Theo thời gian:
    #CPI là tổ chức khủng bố đứng thứ 12 về số cuộc tấn công tính tổng tất cả các năm
    #Tổng số cuộc tấn công mà CPI thực hiện là 1878 vụ, với 3,947 nạn nhân, trong đó có 742 người chết
    #CPI bắt đầu khủng bố được biết đến vào năm 2005, số lượng các vụ tấn công tăng dần, đỉnh điểm là 2010 với hơn 500 vụ.
    #Từ 2010 tới 2017 giảm thê thảm. Tới 2017 chỉ còn hơn 100 vụ (chắc bị chính quyền đàn áp)
    
#Quốc gia và khu vực hoạt động: 
    #CPI hoạt động ở Ấn Độ, với tổng số cuộc khủng bố là 1878, trong đó 1877 vụ là ở Ấn Độ, 1 vụ ở Nepal 
    
#Hình thức khủng bố chủ yếu của CPI và tương quan với thế giới:
    #Các chỉ số của CPI khá khác so với thế giới. CPI có tỉ lệ sử dụng Armed Assault nhiều hơn Bombing, thế giới thì ngươc lại.
    #CPI cũng có tỉ lệ nhiều cuộc tấn công vào cơ sở hạ tầng hơn, còn Assassination ít hơn. Thế giới thì ngược lại.
    #Và có nhiều khả năng là 1 cuộc bắt cóc hơn.

#Quy mô và số người ảnh hưởng/ tương quan với thế giới:
    #SỐ NGƯỜI BỊ ẢNH HƯỞNG (CHẾT + BỊ THƯƠNG):
        #Trung bình trong 1 vụ khủng bố do CPI gây nên, tỉ lệ người bị ảnh hưởng là 2 người. 
        #Thấp hơn so với trung bình trong 1 vụ khủng bố ngẫu nhiên trên thế giới- 5 người
    #TỈ LỆ NGƯỜI CHẾT (SỐ NGƯỜI CHẾT/SỐ NGƯỜI BỊ ẢNH HƯỞNG)
        #Trong 1 vụ khủng bố do CPI gây nên, nếu bạn là người bị ảnh hưởng, bạn sẽ có 40,72% sẽ CHẾT !!
        #Hay nói cách khác, bạn có 59,27% sống sót!!!
        #Cao hơn so với 1 vụ khủng bố ngẫu nhiên trên thế giới- có 32,94% khả năng CHẾT và tới 67,06% sống

# %% [markdown]
# # Phân tích 1.3: Hiện trạng ở Việt Nam

# %%
#Country code của VN là 223
data_phantich[data_phantich.country==223]
#Nhìn vào thì ta có thể thấy VN từ năm 1992 đến 2017 có 12 vụ khủng bố. Với đa phần các vụ là nặc danh (tự phát). 
#Dễ thấy nhất là năm 2017, có 2 vụ khủng bố thực hiện bởi Provisional National Government of Vietnam (hội 3 que)
#Thương vong nhiều nhất là vào năm 1994 với 21 người bị thương và 1995 với 5 người. Còn lại hầu như không đáng kể.
# Out:
#         year  month  day  country  region  success  suicide  attacktype  \
# 52821   1992      9    4      223       5        1        0           4
# 57514   1994     10   13      223       5        1        0           3
# 60874   1995     11    2      223       5        1        0           3
# 62986   1996      7   28      223       5        1        0           9
# 65048   1997      3   28      223       5        1        0           2
# 65527   1997      6    4      223       5        1        0           1
# 71862   2001      2   10      223       5        0        0           8
# 71886   2001      2   14      223       5        0        0           8
# 71929   2001      2   23      223       5        0        0           8
# 72008   2001      3   10      223       5        0        0           8
# 173772  2017      4    8      223       5        1        0           7
# 174170  2017      4   22      223       5        0        0           7
#
# ...

# %%
#Phân tích hình thức tấn công
data[data.country==223]['attacktype1_txt'].value_counts() #7: Tấn công CSHT, #3: Tấn công bằng bom
# Out:
# Unarmed Assault                   4
# Facility/Infrastructure Attack    2
# Bombing/Explosion                 2
# Armed Assault                     1
# Assassination                     1
# Hijacking                         1
# Unknown                           1
# Name: attacktype1_txt, dtype: int64

# %%
#Cuộc tấn công gây thiệt hại nhất là vào năm 1994, được thực hiện bằng bom
#Hội 3 que tấn công 2 lần đều vào cơ sở hạ tầng, nhưng không có ai ảnh hướng

# %%
#Phân tích thương vong:
x=data_phantich[data_phantich.country==223]['year']
y=data_phantich[data_phantich.country==223]['criticalrate']
plt.scatter(x,y)

# %%
#Kết luận:
#VN yên bình quá !!!!

# %%
datadeath.to_csv('datadeath.csv')
data_phantich.to_csv('data_phantich.csv')

# %% [markdown]
# # REPORT

# %% [markdown]
# MỤC LỤC
#
# 1.Phân tích quốc gia và vùng miền hay bị khủng bố nhất.
#
# 2.Phân tích về các tổ chức khủng bố, bao gồm:
#
#     a)Tổng quan + Theo thời gian
#     b)Cách thức tấn công hay dùng
#     c)Quy mô và số người ảnh hưởng
#
# 3.Tổng quan về tình hình khủng bố ở Việt Nam
#
# 4.Google Data Studio

# %% [markdown]
# # 1.PHÂN TÍCH VỀ QUỐC GIA VÀ VÙNG MIỀN HAY BỊ KHỦNG BỐ:

# %% [markdown]
# 10 quốc gia đó là:
#
#     95: Iraq-Middle East & North Africa
#     153: Pakistan-Middle East & North Africa
#     4:Afghanistan-South Asia
#     92:India-South Asia
#     45:Columbia-South America
#     160:Phillipin-Southeast Asia
#     159:Peru-South America
#     61: El Salvador-Central America & Caribbean
#     603:Eritrea-Western Europe
#     209:Turkey-Middle East & North Africa

# %%
k=plt.imread(r'C:\Users\DELL\Pictures\Untitled.png')
plt.imshow(k)

# %% [markdown]
# # 2.PHÂN TÍCH VỀ CÁC TỔ CHỨC KHỦNG BỐ

# %%
#Check data:
data_phantich['terrorname'].value_counts().head(21)
#Đây là 20 tổ chức hàng đầu (bỏ Unknown). Có 19/20 tổ chức có số vụ thực hiện trên 1000
#funfact nhỏ: Có communist party of India cũng được xem là 1 tổ chức khủng bố
#Mình quyết định chọn 2 tổ chức mà mình cảm thấy hứng thú để phân tích: 
    #Taliban
    #Communist Party of India - Maoist (CPI-Maoist)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# ...

# %% [markdown]
# # Taliban

# %% [markdown]
# Tổng quan+ Theo thời gian:
#
#     Taliban là tổ chức khủng bố thực hiện nhiều cuộc tấn công nhất tính tổng tất cả các năm.
#     Tổng số cuộc tấn công mà Taliban thực hiện là 7478 vụ, với 54,459 nạn nhân, trong đó có 26,590 người chết.
#     Taliban bắt đầu các cuộc tấn công được biết đến vào năm 1995, với 4 vụ.
#
# Quốc gia và khu vực hoạt động:
#
#     Taliban hoạt động chủ yếu ở 3 quốc gia là Afghanistan,Pakistan,Turkmenistan.
#     Trong đó Afghanistan chiếm đến 99,3 tổng số cuộc tấn công của Taliban, tương đương với 7423 vụ.
#
# Hình thức khủng bố chủ yếu của Taliban và tương quan với thế giới:
#
#     Các chỉ số về attacktype của Taliban gần như tương đồng với cả thế giới với các loại hình:Bombing,Armed Assault, Kidnapping, Assassination, Facility/Infrastructure Attack.
#     Điều này cũng dễ hiểu vì Taliban là tổ chức có nhiều số vụ khủng bố nhất.
#     Taliban ít khả năng sử dụng Bombing trong 1 cuộc tấn công hơn(38.3% so với 48,6%),thay vào đó là Armed Assault (28,4$ so với 23,5%).
#
# Quy mô và số người ảnh hưởng/ tương quan với thế giới:
#
#     SỐ NGƯỜI BỊ ẢNH HƯỞNG (CHẾT + BỊ THƯƠNG):
#         Trung bình trong 1 vụ khủng bố do Taliban gây nên, tỉ lệ người bị ảnh hưởng là 8 người.
#         Cao hơn so với trung bình trong 1 vụ khủng bố ngẫu nhiên trên thế giới- 5 người.
#
#     TỈ LỆ NGƯỜI CHẾT (SỐ NGƯỜI CHẾT/SỐ NGƯỜI BỊ ẢNH HƯỞNG):
#         Trong 1 vụ khủng bố do Taliban gây nên, nếu bạn là người bị ảnh hưởng, bạn sẽ có 51,24% sẽ CHẾT !!
#         Hay nói cách khác, bạn sẽ chỉ có 48,76% sống sót!!!
#         Cao hơn nhiều so với 1 vụ khủng bố ngẫu nhiên trên thế giới- chỉ có 32,94% khả năng CHẾT và tới 67,06% sống.

# %% [markdown]
# # Communist Party in India

# %% [markdown]
# Tổng quan+ Theo thời gian:
#
#     CPI là tổ chức khủng bố đứng thứ 12 về số cuộc tấn công tính tổng tất cả các năm
#     Tổng số cuộc tấn công mà CPI thực hiện là 1878 vụ, với 3,947 nạn nhân, trong đó có 742 người chết
#     CPI bắt đầu khủng bố được biết đến vào năm 2005, số lượng các vụ tấn công tăng dần, đỉnh điểm là 2010 với hơn 500 vụ.
#     Từ 2010 tới 2017 giảm thê thảm. Tới 2017 chỉ còn hơn 100 vụ (chắc bị chính quyền đàn áp)
#
# Quốc gia và khu vực hoạt động:
#
#     CPI hoạt động ở Ấn Độ, với tổng số cuộc khủng bố là 1878, trong đó 1877 vụ là ở Ấn Độ, 1 vụ ở Nepal
#
# Hình thức khủng bố chủ yếu của CPI và tương quan với thế giới:
#
#     Các chỉ số của CPI khá khác so với thế giới. CPI có tỉ lệ sử dụng Armed Assault nhiều hơn Bombing, thế giới thì ngươc lại.
#     CPI cũng có tỉ lệ nhiều cuộc tấn công vào cơ sở hạ tầng hơn, còn Assassination ít hơn. Thế giới thì ngược lại.
#     Và có nhiều khả năng là 1 cuộc bắt cóc hơn.
#
# Quy mô và số người ảnh hưởng/ tương quan với thế giới:
#
#     SỐ NGƯỜI BỊ ẢNH HƯỞNG (CHẾT + BỊ THƯƠNG):
#         Trung bình trong 1 vụ khủng bố do CPI gây nên, tỉ lệ người bị ảnh hưởng là 2 người.
#         Thấp hơn so với trung bình trong 1 vụ khủng bố ngẫu nhiên trên thế giới- 5 người
#
#     TỈ LỆ NGƯỜI CHẾT (SỐ NGƯỜI CHẾT/SỐ NGƯỜI BỊ ẢNH HƯỞNG)
#         Trong 1 vụ khủng bố do CPI gây nên, nếu bạn là người bị ảnh hưởng, bạn sẽ có 40,72% sẽ CHẾT !!
#         Hay nói cách khác, bạn có 59,27% sống sót!!!
#         Cao hơn so với 1 vụ khủng bố ngẫu nhiên trên thế giới- có 32,94% khả năng CHẾT và tới 67,06% sống

# %% [markdown]
# # 3.Tổng quan Việt Nam

# %% [markdown]
# Nhìn vào thì ta có thể thấy VN từ năm 1992 đến 2017 có 12 vụ khủng bố. Với đa phần các vụ là nặc danh (tự phát).
#
# Dễ thấy nhất là năm 2017, có 2 vụ khủng bố thực hiện bởi Provisional National Government of Vietnam (hội 3 que).
#
# Thương vong nhiều nhất là vào năm 1994 với 21 người bị thương và 1995 với 5 người. Còn lại hầu như không đáng kể.

# %% [markdown]
# # 4. Google Data Studio

# %% [markdown]
# Do em không load được data global terrorism lên Data Studio ( do quá nặng), nên em đã sử dụng 1 dataset khác để làm data studio đó là dataset worldcup ạ. Mong anh chị chấp nhận ạ
#
# Link Google Data Studio: https://datastudio.google.com/u/0/reporting/1FXwN_xF8xfWMPYEPPdovn89LixA2uY4S/page/uqax
