# %% [markdown]
# # GLOBAL TERRORISM ANALYSING
#
# ## Introduction & Dataset
# This is the global terrorism dataset from Kaggle ([link](https://www.kaggle.com/START-UMD/gtd)). This dataset has 181691 rows × 135 columns. The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017.
#
# I did it when I was learning the basic Data Science class Hasbrain. Since it is a huge dataset (at least to newbie), I was one of 2 people who chose to do it among 5 datasets given(class size: 20)
#
# I was first done this file in Vietnamese to complete the assignment. This version is the English- translated from the original one. Hence, some lines may include Vietnamese
#
# ## Objective
# This is a big dataset, so I just chose 3 targets to explore this dataset:
#
# **Which countries are most frequently terrorized?**
#
# **Terrorism Organizations and their active ranges?**
#
# **Vietnam's situation?**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Asus\Downloads\globalterrorismdb_0718dist.csv',encoding = "ISO-8859-1")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 0       197000000001   1970       7     2                  NaN         0
# 1       197000000002   1970       0     0                  NaN         0
# 2       197001000001   1970       1     0                  NaN         0
# 3       197001000002   1970       1     0                  NaN         0
# 4       197001000003   1970       1     0                  NaN         0
# 5       197001010002   1970       1     1                  NaN         0
# 6       197001020001   1970       1     2                  NaN         0
# 7       197001020002   1970       1     2                  NaN         0
# 8       197001020003   1970       1     2                  NaN         0
# 9       197001030001   1970       1     3                  NaN         0
# 10      197001050001   1970       1     1                  NaN         0
# 11      197001060001   1970       1     6                  NaN         0
# ...

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# # PRE- PROCESSING

# %%
#After take a long look into those 135 columns, I decided to take only some to analyze:
dict1={'year':data['iyear'],'month':data['imonth'],'day':data['iday'],'country':data['country'],'region':data['region'],
       'success':data['success'],'suicide':data['suicide'],'attacktype':data['attacktype1'],'terrorname':data['gname'],
       'PIC':data['nperps'],'death':data['nkill'],'wound':data['nwound']}
data_phantich=pd.DataFrame(dict1) # I will use the "data_phantich" to analyze from now

# %%
#check data:
data_phantich['country'].isnull().value_counts() #The data all non-null(False:181691)-> no need to clean
data_phantich['region'].isnull().value_counts()# Same with the "country" checking
data_phantich[data_phantich.country=='Unknown']['country'].value_counts()
data_phantich[data_phantich.country=='Unknown']['country'].value_counts()
# ==> So, we don't need to clean or drop any lines for this dataset
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Series([], Name: country, dtype: int64)

# %% [markdown]
# # WHICH COUNTRY ARE MOST FREQUENTLY TERRORIZED?

# %%
#Top 10 countries were frequently terrorized:
data_phantich['country'].value_counts().head(10) # Count the number of cases listed
#10 countries are:
    #95: Iraq-Middle East & North Africa
    #153: Pakistan-Middle East & North Africa
    #4:Afghanistan-South Asia
    #92:India-South Asia
    #45:Columbia-South America
    #160:Phillipin-Southeast Asia
    #159:Peru-South America
    #61: El Salvador-Central America & Caribbean
    #603:Eritrea-Western Europe
    #209:Turkey-Middle East & North Africa
# Out:
# 95     24636
# 153    14368
# 4      12731
# 92     11960
# 45      8306
# 160     6908
# 159     6096
# 61      5320
# 603     5235
# 209     4292
# Name: country, dtype: int64

# %%
#plot the chart of those 10 countries above:
y=[24636,14368,12731,11960,8306,6908,6096,5320,5235,4292]
x=['Iraq', 'Parkistan', 'Afghanistan', 'India','Columbia','Phillipin','Peru','El Salvador','Eritrea','Turkey']
plot=plt.bar(x,y,color='red',align='edge')
plot[0].set_color('r')
plot[1].set_color('r')
plot[2].set_color('green')
plot[3].set_color('green')
plot[4].set_color('orange')
plot[5].set_color('blue')
plot[6].set_color('orange')
plot[7].set_color('black')
plot[8].set_color('purple')
plot[9].set_color('r')
plt.xlabel('top countries')
plt.ylabel('numbers of terrorisms')
plt.xticks(x, x, fontsize=9, rotation=30)
plt.title('Top 10 countries with most terrorism')
plt.show()

# %%
#plotted the number of terrorism in term of year happened;
y=list(data_phantich['year'].value_counts())
x=[2014,
2015,
2016,
2013,
2017,
2012,
2011,
1992,
2010,
2008,
2009,
1991,
1989,
1990,
1988,
1984,
1994,
2007,
1997,
1987,
1995,
1996,
1985,
1983,
1986,
2006,
1979,1980,1981,1982,2005,2001,2000,1978,1999,2002,1977,2003,2004,1998,1976,1975,1970,1974,1972,1973,1971] 
#The x list was created a little bit clumsy
plt.scatter(x,y)

# %% [markdown]
# As we can see, the number of terrorisms were gradually increasing through year. Since 2010 to 2014 the number of terrorisms had raised polynomially. But then it decreased. I guessed the increase was because of the IS, and the decrease was thanks to the efforts of USA and other countries in flatted out those terrorists.

# %% [markdown]
# # TERRORISM ORGANIZATIONS AND THEIR ACTIVE RANGE?

# %%
#Check data:
data_phantich['terrorname'].value_counts().head(21)
#Top 20 terrorism organizations (without Unknown). There are 19/20 organizations did more than 1000 time terrorizing.
#small funfact: The communist party of India was treat as a terrorism organization. 
#After taking a look, I decided to choose 2 organistions which I found interesting to go deep through: 
    #Taliban
    #Communist Party of India - Maoist (CPI-Maoist) (Because my country- Vietnam also Communism follower too, so it just a little bit curious haha)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# ...

# %%
#Plotted data:
datagroup=pd.DataFrame({'count' : data_phantich.groupby( [ "terrorname"] ).size().sort_values(ascending=False).head(21)}).reset_index()
datagroup=datagroup[datagroup.terrorname != 'Unknown']
plt.barh(datagroup['terrorname'],datagroup['count'],color='orange')
plt.title('Top 20 terrorism organisation based on number of terrorism done')
# Out:
# Text(0.5, 1.0, 'Top 20 terrorism organisation based on number of terrorism done')

# %% [markdown]
# ## TALIBAN

# %% [markdown]
# To analyze deep through Taliban and CPI- Maoist, I will use the original dataset ("data") together with the "data_phantich", since the original dataset has many features
#
# I will use those features below:
#
# **Time doing terrorisms**
#
# **Attack types (not considering Suicide)**
#
# **Attack range & size**

# %%
#By time
data[data.gname=='Taliban']['iyear'].value_counts()
#We can see 1995 is the oldest year of Taliban's attacks ==> Can assume that Taliban first start its work officially in 1995
#Plotted data:
y=list(data[data.gname=='Taliban']['iyear'].value_counts())
x=[2015,2016,2014,2017,2012,2013,2010,2009,2008,2011,2007,2006,2005,2004,2003,2002,1995,2001]
plt.scatter(x,y)

# %%
data[data.gname=='Taliban'].country_txt.value_counts()
#We can easily see the attack range of Taliban in term of country was only in Afghanistan,Pakistan, Turkmenistan
# Out:
# Afghanistan     7423
# Pakistan          54
# Turkmenistan       1
# Name: country_txt, dtype: int64

# %%
#On the initial look to the data, I saw some org such as Al-Qaida has smaller branch in other countries which not listed in the master branch
#So I will check weather Taliban is similar to them or not:
for i in data['gname']:
    if 'taliban' in str(i).lower():
        i='Taliban'
data[data.gname=='Taliban'].country_txt.value_counts()
# ==> the numbers below don't change, so we could be comfortable that it just 1 Taliban org listed in this Dataset
# Out:
# Afghanistan     7423
# Pakistan          54
# Turkmenistan       1
# Name: country_txt, dtype: int64

# %%
#plotted a pie chart( little bit ugly)
colors=['gray','orange','b']
label=['Afghanistan','Pakistan','Turkmenistan']
plt.pie(data[data.gname=='Taliban'].country_txt.value_counts(), labels=label,colors=colors, startangle=180, autopct='%.1f%%')
plt.title('Active range (countries) of Taliban')
plt.show()

# %%
#By Attacktypes:
data[data.gname=='Taliban']['attacktype1_txt'].value_counts()
#Plotted pie chart:
fig, (ax1, ax2) = plt.subplots(1, 2)
dothi=[2866,2125,713,508,235,33+19+13+966]
label=['Bombing/Explosion','Armed Assault','Kidnapping','Assassination','Facility/Infrastructure Attack','Others+Unknown']
ax1.pie(dothi, startangle=180, autopct='%.1f%%')
#Compared attack types of Taliban to attack types of global:
data['attacktype1_txt'].value_counts()
#Plotted pie chart:
dothi1=[88255,42669,19312,11158,10356,7276+1015+991+659]
ax2.pie(dothi1, startangle=180, autopct='%.1f%%')
plt.legend(label,loc='lower right',bbox_to_anchor=(1, 1),fontsize=8)
plt.show()

#Based on the charts below:
#attacktype statisticof Taliban is nearly the same to the world's. 
#This was reasonable because Taliban were org with most attacks done
#Taliban was least possible to use Bombing in an attack compare to the world in general, instead it was Armed Assault

# %%
#By size:
#For simple, we calculate the damage of an attack by the method (I self created): damage=death+ wounded
data_phantich['criticalrate']=data_phantich['death']+data_phantich['wound']
#drop the nulls (some did not have death and some did not have wound, but it was a very small number compared to the analyzing one:
datadeath=data_phantich.dropna(axis=0,subset=['death','wound','criticalrate'])
#Calculated the average in damage of Taliban compared to the world's
datadeath[datadeath.terrorname=='Taliban']['criticalrate'].mean()#==7.9109529343405
datadeath['criticalrate'].mean() #==5.296128433353355
#=> Taliban có mức độ thiệt hại cao hơn so với mức trung bình toàn cầu trong 1 vụ tấn công 
#=> In average, Taliban's attack caused higher damage compared to world's
data_phantich['deathrate']=data_phantich['death']/(data_phantich['death']+data_phantich['wound'])
datadeath['deathrate']=datadeath['death']/(datadeath['death']+datadeath['wound'])
datadeath['deathrate'].fillna(value=0,axis=0,inplace=True)
#Calculate the death rate of Taliban's attack compared to the world's:
datadeath[datadeath.terrorname=='Taliban']['deathrate'].mean() #0.512434661134669
datadeath['deathrate'].mean() #0.32942326312248466
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# 0.32942326312248466

# %%
#Sum up the attack size of Taliban:
#AFFECTED NUMBER (DEATH + WOUNDED):
    #On average, in an attack caused by Taliban, the affected people were 8
    #Higher than the world's average (5 people)
#DEATH RATE (DEATH/AFFECTED NUMBER)
    # If you were in an Taliban's attack, you would have 51,24% of death chance !!!
    #In other way, you just have 48,76% survival chance!!!
    #Extremely higher than a random attack from world- only 32,94% death rate and 67,06% survive!!!
    
#==> Taliban was extremely dangerous!

# %%
#SUM-UP TALIBAN:
#Overall+ By time:
    #Taliban was an organisation that had done highest number of attacks in the world (all year sum)
    #Total attacks made by Taliban was 7478, with 54,459 victims, with 26,590 dead people
    #Taliban first started its attracks in 1995, with 4 attacks made in that year
    
#Active range in term of countries: 
    #Mostly in 3 countries Afghanistan,Pakistan,Turkmenistan. 
    # Afghanistan was took 99,3% attacks of Taliban (7423 attacks)
    
#Taliban's attacktypes:
    #attacktype statisticof Taliban is nearly the same to the world's. 
    #This was reasonable because Taliban were org with most attacks done
    #Taliban was least possible to use Bombing in an attack compare to the world in general, instead it was Armed Assault
    
#Attack size and affected people (compared to the world's):
    #AFFECTED NUMBER (DEATH + WOUNDED):
        #On average, in an attack caused by Taliban, the affected people were 8
        #Higher than the world's average (5 people)
    #DEATH RATE (DEATH/AFFECTED NUMBER)
        # If you were in an Taliban's attack, you would have 51,24% of death chance !!!
        #In other way, you just have 48,76% survival chance!!!
        #Extremely higher than a random attack from world- only 32,94% death rate and 67,06% survive!!!

# %% [markdown]
# ## COMMUNIST PARTY IN INDIA (CPI- MAOIST)

# %%
#By time
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['iyear'].value_counts()
#Plotted scatterplot:
y=list(data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['iyear'].value_counts())
x=[2010,2009,2011,2008,2017,2016,2015,2014,2012,2013,2006,2005,2007]
plt.scatter(x,y)
#CPI started its first attacks in 2005, the peak was in 2010 with more than 500 attacks.

# %%
#Attack range in term of countries
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)'].country_txt.value_counts()
#CPI maily terrorized in India, with total attacks of 1878, 1877 was in India, 1 in Nepal
# Out:
# India    1877
# Nepal       1
# Name: country_txt, dtype: int64

# %%
#Attacktype of CPI:
data[data.gname=='Communist Party of India - Maoist (CPI-Maoist)']['attacktype1_txt'].value_counts()
#Plotted pie chart:
fig, (ax1, ax2) = plt.subplots(1, 2)
dothi=[547,577,307,52,282,68+21+52+7]
label=['Bombing/Explosion','Armed Assault','Kidnapping','Assassination','Facility/Infrastructure Attack','Others+Unknown']
ax1.pie(dothi, startangle=180, autopct='%.1f%%')
#Compared to the world's:
data['attacktype1_txt'].value_counts()
#Plotted pie chart:
dothi1=[88255,42669,19312,11158,10356,7276+1015+991+659]
ax2.pie(dothi1, startangle=180, autopct='%.1f%%')
plt.legend(label,loc='lower right',bbox_to_anchor=(1, 1),fontsize=8)
plt.show()

#Conclusion:
#CPI's attacktype rates are quite different than the world's. CPI had high chance to use Armed Assault than Bombing, while the world was in contrary.
#CPI had more attack in the Infrastructure, and little attack in Assassination. The world was in contrary.
#And there was high chance to be a Kidnapping.

# %%
#Attack size:
#AFFECTED NUMBER:
datadeath[datadeath.terrorname=='Communist Party of India - Maoist (CPI-Maoist)']['criticalrate'].mean() #2.1639254385964914
datadeath['criticalrate'].mean() #5.296128433353355
#DEATH RATE:
datadeath[datadeath.terrorname=='Communist Party of India - Maoist (CPI-Maoist)']['deathrate'].mean() #0.407241325135677
datadeath['deathrate'].mean() #0.32942326312248466
# Out:
# 0.32942326312248466

# %%
#SUM-UP COMMINIST PARTY IN INDIA (CPI):
#Overall+ By time:
    #CPI was ranked 12th about number of attacks (all years sum)
    #Number of attacks made by CPI was 1878 vụ, 3,947 victims, 742 people died.
    #CPI started its first attacks in 2005, the peak was in 2010 with more than 500 attacks.
    #From 2010 to 2017 witnessed a poor drop in number of attacks. Until 2017 it was just did 100 attacks (may be it was slayed by the efforts of Gorvenment)
    
#Active range in term of countries: 
    #CPI maily terrorized in India, with total attacks of 1878, 1877 was in India, 1 in Nepal
    
#CPI's Attacktypes:
    #CPI's attacktype rates are quite different than the world's. CPI had high chance to use Armed Assault than Bombing, while the world was in contrary.
    #CPI had more attack in the Infrastructure, and little attack in Assassination. The world was in contrary.
    #And there was high chance to be a Kidnapping.

#Attack size and affected people (compared to the world's):
    #AFFECTED NUMBER:
        #In an attack made by CPI, number of affected people was 2. 
        #Lower than the world's average (5 people)
    #DEATH RATE
        #If you were in an CPI's attack, you would have 40,72% of death chance !!!
        # ==>59,27% survival chance!!!
        #Higher than a random attack from world- only 32,94% death rate and 67,06% survive!!!

# %% [markdown]
# # VIETNAM SITUATION

# %%
#Country code of Vietnam was 223
data_phantich[data_phantich.country==223]
#Looked at the table below, we could see from 1992 to 2017 has 12 attacks. Most of them were unknown (had been done amateurly)
#In 2017, there were 2 attacks made by Provisional National Government of Vietnam (which in Vietnam we call them The 3-Stick Organisation)
#Most damaged attack was in 1994 with 21 wounded people, and in 1995 with 5 people. The rest were trivial
# Out:
#         year  month  day  country  region  success  suicide  attacktype  \
# 52821   1992      9    4      223       5        1        0           4
# 57514   1994     10   13      223       5        1        0           3
# 60874   1995     11    2      223       5        1        0           3
# 62986   1996      7   28      223       5        1        0           9
# 65048   1997      3   28      223       5        1        0           2
# 65527   1997      6    4      223       5        1        0           1
# 71862   2001      2   10      223       5        0        0           8
# 71886   2001      2   14      223       5        0        0           8
# 71929   2001      2   23      223       5        0        0           8
# 72008   2001      3   10      223       5        0        0           8
# 173772  2017      4    8      223       5        1        0           7
# 174170  2017      4   22      223       5        0        0           7
#
# ...

# %%
#Attacktypes:
data[data.country==223]['attacktype1_txt'].value_counts()
# Out:
# Unarmed Assault                   4
# Facility/Infrastructure Attack    2
# Bombing/Explosion                 2
# Unknown                           1
# Assassination                     1
# Armed Assault                     1
# Hijacking                         1
# Name: attacktype1_txt, dtype: int64

# %%
#The most damaged attack was made in 1994, attacked using Bomb
#The Provisional Gorvernment of Vietnam 2 times attacked in the infrastructure, but nobody was affected or damaged.

# %%
#Affected number:
x=data_phantich[data_phantich.country==223]['year']
y=data_phantich[data_phantich.country==223]['criticalrate']
plt.scatter(x,y)

# %%
#My conclusion:
#Vietnam is so peaceful !!!!

# %%
#Save the data
datadeath.to_csv('datadeath.csv')
data_phantich.to_csv('data_phantich.csv')

# %% [markdown]
# # FINAL REPORT

# %% [markdown]
# TABLE OF CONTENTS
#
# **1.Countries that were most frequently terrorized**
#
# **2.Terrorism Organisation analysing, including:**
#
#     a)Overall + By attacking time
#     b)Attacktypes
#     c)Affected number and death rate
#
# **3.Vietnam's situation**

# %% [markdown]
# ## 1. COUNTRIES THAT WERE MOST FREQUENTLY TERRORIZED

# %% [markdown]
# 10 countries:
#
#     95: Iraq-Middle East & North Africa
#     153: Pakistan-Middle East & North Africa
#     4:Afghanistan-South Asia
#     92:India-South Asia
#     45:Columbia-South America
#     160:Phillipin-Southeast Asia
#     159:Peru-South America
#     61: El Salvador-Central America & Caribbean
#     603:Eritrea-Western Europe
#     209:Turkey-Middle East & North Africa

# %%
k=plt.imread(r'C:\Users\DELL\Pictures\Untitled.png') ## saved and plotted a plotted (which was represented above)
plt.imshow(k)

# %% [markdown]
# ## 2.TERRORISM ORGANISATION ANALYZING

# %%
#Check data:
data_phantich['terrorname'].value_counts().head(21)
#Top 20 terrorism organizations (without Unknown). There are 19/20 organizations did more than 1000 time terrorizing.
#small funfact: The communist party of India was treat as a terrorism organization. 
#After taking a look, I decided to choose 2 organistions which I found interesting to go deep through: 
    #Taliban
    #Communist Party of India - Maoist (CPI-Maoist)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# ...

# %% [markdown]
# ### Taliban

# %% [markdown]
# Overall+ By time:
#
#     Taliban was an organisation that had done highest number of attacks in the world (all year sum)
#     Total attacks made by Taliban was 7478, with 54,459 victims, with 26,590 dead people
#     Taliban first started its attracks in 1995, with 4 attacks made in that year
#
# Active range in term of countries:
#
#     Mostly in 3 countries Afghanistan,Pakistan,Turkmenistan.
#     Afghanistan was took 99,3% attacks of Taliban (7423 attacks)
#
# Taliban's attacktypes:
#
#     Attacktype statisticof Taliban is nearly the same to the world's.
#     This was reasonable because Taliban were org with most attacks done
#     Taliban was least possible to use Bombing in an attack compare to the world in general, instead it was Armed Assault
#
# Attack size and affected people (compared to the world's):
#
#     AFFECTED NUMBER (DEATH + WOUNDED):
#         On average, in an attack caused by Taliban, the affected people were 8
#         Higher than the world's average (5 people)
#     DEATH RATE (DEATH/AFFECTED NUMBER)
#         If you were in an Taliban's attack, you would have 51,24% of death chance !!!
#         In other way, you just have 48,76% survival chance!!!
#         Extremely higher than a random attack from world- only 32,94% death rate and 67,06% survive!!!

# %% [markdown]
# ### Communist Party in India

# %% [markdown]
# Overall+ By time:
#
#     CPI was ranked 12th about number of attacks (all years sum)
#     Number of attacks made by CPI was 1878 vụ, 3,947 victims, 742 people died.
#     CPI started its first attacks in 2005, the peak was in 2010 with more than 500 attacks.
#     From 2010 to 2017 witnessed a poor drop in number of attacks. Until 2017 it was just did 100 attacks (may be it was slayed by the efforts of Gorvenment)
#
# Active range in term of countries:
#
#     CPI maily terrorized in India, with total attacks of 1878, 1877 was in India, 1 in Nepal
#
# CPI's Attacktypes:
#
#     CPI's attacktype rates are quite different than the world's. CPI had high chance to use Armed Assault than Bombing, while the world was in contrary.
#     CPI had more attack in the Infrastructure, and little attack in Assassination. The world was in contrary.
#     And there was high chance to be a Kidnapping.
#
# Attack size and affected people (compared to the world's):
#
#     AFFECTED NUMBER:
#         In an attack made by CPI, number of affected people was 2.
#         Lower than the world's average (5 people)
#     DEATH RATE
#         If you were in an CPI's attack, you would have 40,72% of death chance !!!
#         ==>59,27% survival chance!!!
#         Higher than a random attack from world- only 32,94% death rate and 67,06% survive!!!

# %% [markdown]
# ### Vietnam situation

# %% [markdown]
# Looked at the table below, we could see from 1992 to 2017 has 12 attacks. Most of them were unknown (had been done amateurly)
#
# In 2017, there were 2 attacks made by Provisional National Government of Vietnam (which in Vietnam we call them The 3-Stick Organisation)
#
# Most damaged attack was in 1994 with 21 wounded people, and in 1995 with 5 people. The rest were trivial.
